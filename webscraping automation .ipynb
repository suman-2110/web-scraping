# %%
from bs4 import BeautifulSoup as soup
import bs4
import requests
from selenium import webdriver


res = requests.get('https://www.firstpost.com/firstcricket/results/series/icc-cricket-world-cup-2019.html')
type(res)
res.text
soup = bs4.BeautifulSoup(res.text,'html.parser')
print(res.text[:2])
star = soup.select("ul.results-list")
len("ul.results-list")
star
for i in soup.select("ul.results-list"):
    print(i.text)
    
chrome_path=r"C:\Users\rr900\Downloads\chromedriver_win32 (1)\chromedriver.exe"
driver=webdriver.Chrome(chrome_path)
# Out:
# 	<
#
#
# Jun 30th, 2019 - Match 38
# England Vs India, Edgbaston, Birmingham
# Result - England beat India by 31 runs
# Scorecard
#
#
# Jun 29th, 2019 - Match 37
# New Zealand Vs Australia, Lord's, London
# Result - Australia beat New Zealand by 86 runs
# Scorecard
#
#
# Jun 29th, 2019 - Match 36
# Pakistan Vs Afghanistan, Headingley, Leeds
# Result - Pakistan beat Afghanistan by 3 wickets
# Scorecard
#
#
# Jun 28th, 2019 - Match 35
# Sri Lanka Vs South Africa, Riverside Ground, Chester-le-Street
# Result - South Africa beat Sri Lanka by 9 wickets
# Scorecard
#
#
# Jun 27th, 2019 - Match 34
# West Indies Vs India, Old Trafford, Manchester
# Result - India beat West Indies by 125 runs
# Scorecard
#
#
# Jun 26th, 2019 - Match 33
# New Zealand Vs Pakistan, Edgbaston, Birmingham
# Result - Pakistan beat New Zealand by 6 wickets
# Scorecard
#
#
# Jun 25th, 2019 - Match 32
# England Vs Australia, Lord's, London
# Result - Australia beat England by 64 runs
# Scorecard
#
#
# ...
